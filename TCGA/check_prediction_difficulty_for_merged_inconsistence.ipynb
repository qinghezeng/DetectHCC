# %%
import os
import pandas as pd
import numpy as np

# %%
path = "/media/visiopharm5/WDGold/deeplearning/Hepatocarcinomes/TCGA/merge_series"

# %%
gene_signatures = ["Inflammatory", "Gajewski_13G_Inflammatory", "6G_Interferon_Gamma", 
                   "Interferon_Gamma_Biology", "T-cell_Exhaustion", "Ribas_10G_Interferon_Gamma"]
bestk = [8, 8, 6, 3, 5, 8]

# %%
pd.read_csv(os.path.join(path, "merged_compare_sample_cluster_"+gene_signatures[i]+".csv"))

# %%
for i in range(len(gene_signatures)):
    df = pd.read_csv(os.path.join(path, "merged_compare_sample_cluster_"+gene_signatures[i]+".csv"))
    display(df.head(3))
# Out:
#      Sample Label Individually clustering Merged then clustering
# 0  AAE7.01A    tp            Cluster High           Cluster High
# 1  A9GT.01A    tp            Cluster High           Cluster High
# 2  A8YO.01A    tp            Cluster High           Cluster High
# 3  A5RG.01A    tp            Cluster High           Cluster High
# 4  AADO.01A    tp            Cluster High           Cluster High
#      Sample Label Individually clustering Merged then clustering
# 0  AAE7.01A    tp            Cluster High           Cluster High
# 1  A9GT.01A    tp            Cluster High           Cluster High
# 2  A8YO.01A    tp            Cluster High           Cluster High
# 3  A5RG.01A    tp            Cluster High           Cluster High
# 4  AADO.01A    tp            Cluster High           Cluster High
#          Sample Label Individually clustering Merged then clustering
# 0      A9GT.01A    tp            Cluster High           Cluster High
# ...
