# %%
import numpy as np
import pandas as pd

# %%
root = "E:\\deeplearning\\Hepatocarcinomes\\TCGA\\"

# %%
list_sia = pd.read_excel(root + 'classifier_genes_Sia_UPPER.xlsx')
fpkm = pd.read_csv(root + 'processed\\fpkm_final_log2-median-centering.csv', sep='\t', index_col=0)

# %%
print(list_sia.shape)
display(list_sia.head(5))
print()
print(fpkm.shape)
display(fpkm.head(5))
# Out:
# (112, 3)
#    ID name Gene name class
# 0    PAGE4     PAGE4  Rest
# 1  UGT2B17   UGT2B17  Rest
# 2  C1QTNF3   C1QTNF3  Rest
# 3    DHRS2     DHRS2  Rest
# 4  FAM133A   FAM133A  Rest
# (733, 340)
#            AADA-01A  A5SJ-01A  AACF-01A  A9GZ-01A  A113-01A  A4NK-01A  \
# Gene Name
# A2M        0.580986  0.979374 -0.436710  2.521986  0.771957 -1.358418
# ACVR1C    -0.042060 -0.071784 -0.055145  0.630880 -0.012114  0.468331
# ADAM12     0.013547  0.098334 -0.007120 -0.022410 -0.000270 -0.024944
# ADM       -0.734360  0.301992 -0.439411 -0.878293 -1.283949  0.490239
# ADORA2A    0.716873 -0.105847 -0.342741  0.411041 -0.609093  0.067196
#
#            A3KF-01A  A5NO-01A  AAVX-01A  AAE0-01A  ...  AAW1-01A  A7IL-01A  \
# Gene Name                                          ...
# A2M       -2.809726  0.480985  0.357785  0.992854  ... -2.196092 -1.308245
# ACVR1C    -0.036876  0.389841  0.450002 -0.121834  ...  0.019613 -0.027407
# ...

# %%
print(list_sia["ID name"].values==list_sia["Gene name"].values)
list_sia.drop(columns="ID name", inplace=True)
print(list_sia.shape)
display(list_sia.head(5))
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]
# (112, 2)
#   Gene name class
# 0     PAGE4  Rest
# 1   UGT2B17  Rest
# 2   C1QTNF3  Rest
# 3     DHRS2  Rest
# 4   FAM133A  Rest

# %%
set_nanos = set(fpkm.index.tolist())

# %%
set_sia = set(list_sia["Gene name"].tolist())

# %%
set_overlap = set_nanos.intersection(set_sia)
print(len(set_overlap))
# Out:
# 33

# %%
list_sia = list_sia[list_sia["Gene name"].isin(set_overlap)].reset_index(drop=True)

# %%
fpkm = list_sia.join(fpkm, on="Gene name")

# %%
# Export data
fpkm.to_csv(root + 'processed\\fpkm_final_filtered-Sia_log2-median-centering.csv', index=False, sep='\t')
