# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('E:\\deeplearning\\Hepatocarcinomes\\SlidesClassification\\vgg16_performance_training.csv', delimiter=';', decimal='.')

# %%
# sns.lvplot(x="day", y="total_bill", data=df, palette="mako",
#            #hue = 'smoker',
#            width = 0.8,           # 箱之间间隔比例
#            linewidth = 12,
#            scale = 'area',        # 设置框的大小 → “linear”、“exonential”、“area”
#            k_depth = 'proportion',  # 设置框的数量 → “proportion”、“tukey”、“trustworthy”
#           )
# 绘制LV图

plt.figure(figsize=(20, 15))
plt.ylim(0,1)
sns.set_style("ticks")
sns.set_context("paper")
g=sns.boxplot(order=["Sensitivity (TPR)","Specificity (TNR)","Precision (PPV)","Fall-Out (FPR)","Area under ROC (AUC)",
                   "Accuracy (ACC)","F1-Score","Intersection over Union (IoU)"], data=df, notch=True, meanline=True, 
                  width=0.7, showfliers=False, palette='Set3', capprops = {'linewidth': 6})
g.set_xlabel("Metrics",fontsize=20)
g.set_ylabel("Distribtuion",fontsize=20)
g.tick_params(labelsize=14)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
sns.swarmplot(order=["Sensitivity (TPR)","Specificity (TNR)","Precision (PPV)","Fall-Out (FPR)","Area under ROC (AUC)",
                     "Accuracy (ACC)","F1-Score","Intersection over Union (IoU)"], data=df,color ='k',size = 3,alpha = 0.8)
plt.tight_layout()
plt.savefig('D:\\qinghe\\figures\\final\\res4a_training_metrics.jpg')

# %%
# sns.lvplot(x="day", y="total_bill", data=df, palette="mako",
#            #hue = 'smoker',
#            width = 0.8,           # 箱之间间隔比例
#            linewidth = 12,
#            scale = 'area',        # 设置框的大小 → “linear”、“exonential”、“area”
#            k_depth = 'proportion',  # 设置框的数量 → “proportion”、“tukey”、“trustworthy”
#           )
# 绘制LV图

plt.figure(figsize=(20, 10))
sns.set_style("ticks")
sns.set_context("paper")
g=sns.boxplot(order=["Sensitivity (TPR)","Specificity (TNR)","Precision (PPV)","Area under ROC (AUC)",
                   "Accuracy (ACC)","F1-Score","Intersection over Union (IoU)"], data=df, notch=True, meanline=True, 
                    width=0.65, showfliers=False, palette='Set3', capprops = {'linewidth': 6})
g.set_xlabel("Metrics",fontsize=18)
g.set_ylabel("Distribtuion",fontsize=18)
g.tick_params(labelsize=14)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
sns.swarmplot(order=["Sensitivity (TPR)","Specificity (TNR)","Precision (PPV)","Area under ROC (AUC)",
                     "Accuracy (ACC)","F1-Score","Intersection over Union (IoU)"], data=df,color ='k',size = 3,alpha = 0.8)
plt.tight_layout()
plt.savefig('D:\\qinghe\\figures\\final\\res4b_training_metrics.jpg')

# %%
# sns.lvplot(x="day", y="total_bill", data=df, palette="mako",
#            #hue = 'smoker',
#            width = 0.8,           # 箱之间间隔比例
#            linewidth = 12,
#            scale = 'area',        # 设置框的大小 → “linear”、“exonential”、“area”
#            k_depth = 'proportion',  # 设置框的数量 → “proportion”、“tukey”、“trustworthy”
#           )
# 绘制LV图

plt.figure(figsize=(5,5))
sns.set_style("ticks")
sns.set_context("paper")
g=sns.boxplot(order=["Fall-Out (FPR)"], data=df, notch=True, meanline=True, showfliers=False, palette='Set3', width=0.45)
g.set_ylabel("Distribtuion",fontsize=13)
g.tick_params(labelsize=11)
sns.swarmplot(order=["Fall-Out (FPR)"], data=df,color ='k',size = 3,alpha = 0.8)
plt.tight_layout()
plt.savefig('D:\\qinghe\\figures\\final\\res4c_fpr.jpg')

# %%
# sns.lvplot(x="day", y="total_bill", data=df, palette="mako",
#            #hue = 'smoker',
#            width = 0.8,           # 箱之间间隔比例
#            linewidth = 12,
#            scale = 'area',        # 设置框的大小 → “linear”、“exonential”、“area”
#            k_depth = 'proportion',  # 设置框的数量 → “proportion”、“tukey”、“trustworthy”
#           )
# 绘制LV图

plt.figure(figsize=(3,10))
sns.set_style("ticks")
sns.set_context("paper")
g=sns.boxplot(order=["Fall-Out (FPR)"], data=df, notch=True, meanline=True, showfliers=False, palette='Set3', width=0.2)
# g.set_ylabel("Distribtuion",fontsize=13)
g.tick_params(labelsize=14)
g.tick_params(axis="y",direction="in", pad=-38)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
sns.swarmplot(order=["Fall-Out (FPR)"], data=df,color ='k',size = 3,alpha = 0.8)
plt.tight_layout()
plt.savefig('D:\\qinghe\\figures\\final\\res4c_fpr.png', transparent=True)
